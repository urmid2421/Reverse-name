# %%
my_str = 'EdYoda'
print(my_str[6::-1])
# Out:
# adoYdE

# %%
my_str = 'Hello World, This is Urmi here'
len(my_str)
# Out:
# 30

# %%
my_str = 'Hello World, This is Urmi here'
print(my_str[30: :-1])
# Out:
# ereh imrU si sihT ,dlroW olleH
